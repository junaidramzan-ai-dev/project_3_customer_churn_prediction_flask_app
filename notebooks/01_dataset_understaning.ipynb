# %%
# step 1  import libraries
import numpy as np 
import pandas as pd

# %%
# step2: Load the dataset
df = pd.read_csv('../data/raw/Telco-Customer-Churn.csv')
print(df.head(10))
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges Churn
# 0  7590-VHVEG  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No          No              No  Month-to-month              Yes           Electronic check           29.85        29.85    No
# 1  5575-GNVDE    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No          No              No        One year               No               Mailed check           56.95       1889.5    No
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'], dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# step 4: Check missing values with percentage of each columns
missing = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})

missing.sort_values(
    by="Percentage",
    ascending=False
)
# Out:
#                   Missing Values  Percentage
# customerID                     0         0.0
# gender                         0         0.0
# SeniorCitizen                  0         0.0
# Partner                        0         0.0
# Dependents                     0         0.0
# tenure                         0         0.0
# PhoneService                   0         0.0
# MultipleLines                  0         0.0
# InternetService                0         0.0
# OnlineSecurity                 0         0.0
# OnlineBackup                   0         0.0
# DeviceProtection               0         0.0
# TechSupport                    0         0.0
# StreamingTV                    0         0.0
# StreamingMovies                0         0.0
# Contract                       0         0.0
# PaperlessBilling               0         0.0
# PaymentMethod                  0         0.0
# MonthlyCharges                 0         0.0
# TotalCharges                   0         0.0
# ...

# %%
# step 5: Check duplicates 
print(df.duplicated().sum())
# Out:
# 0

# %%
# step 6: Check statistical summary
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling     PaymentMethod TotalCharges Churn
# count         7043   7043    7043       7043         7043          7043            7043           7043         7043             7043        7043        7043            7043            7043             7043              7043         7043  7043
# unique        7043      2       2          2            2             3               3              3            3                3           3           3               3               3                2                 4         6531     2
# top     3186-AJIEK   Male      No         No          Yes            No     Fiber optic             No           No               No          No          No              No  Month-to-month              Yes  Electronic check         20.2    No
# ...

# %%
# step 7: Check unique values
for column in df.columns:
    print(column)
    print(df[column].nunique())
    print("-"*20)
# Out:
# customerID
# 7043
# --------------------
# gender
# 2
# --------------------
# SeniorCitizen
# 2
# --------------------
# Partner
# 2
# --------------------
# Dependents
# 2
# --------------------
# tenure
# 73
# --------------------
# PhoneService
# 2
# --------------------
# MultipleLines
# 3
# --------------------
# InternetService
# 3
# --------------------
# OnlineSecurity
# 3
# --------------------
# OnlineBackup
# 3
# --------------------
# DeviceProtection
# 3
# --------------------
# TechSupport
# 3
# --------------------
# StreamingTV
# 3
# --------------------
# StreamingMovies
# 3
# --------------------
# Contract
# 3
# --------------------
# PaperlessBilling
# 2
# --------------------
# PaymentMethod
# 4
# --------------------
# MonthlyCharges
# 1585
# --------------------
# TotalCharges
# 6531
# --------------------
# Churn
# 2
# --------------------

# %%
# step 8: Target Values
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Target values in percentage 
df['Churn'].value_counts(normalize=True)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# step 9: Numerical vs Categorical Columns
numerical_columns = df.select_dtypes(include=np.number).columns.tolist()
categorical_columns = df.select_dtypes(exclude=np.number).columns.tolist()

# %%
print("Numerical Features")
print(numerical_columns)
print("-"*40)
print('Categorical Features')
print(categorical_columns)
# Out:
# Numerical Features
# ['SeniorCitizen', 'tenure', 'MonthlyCharges']
# ----------------------------------------
# Categorical Features
# ['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']

# %%
print(df['TotalCharges'].dtype)
# Out:
# object

# %%
# Create a dataset summary
summary = pd.DataFrame({
    "Data Type ": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Unique values": df.nunique()
})

summary
# Out:
#                  Data Type   Missing Values  Unique values
# customerID           object               0           7043
# gender               object               0              2
# SeniorCitizen         int64               0              2
# Partner              object               0              2
# Dependents           object               0              2
# tenure                int64               0             73
# PhoneService         object               0              2
# MultipleLines        object               0              3
# InternetService      object               0              3
# OnlineSecurity       object               0              3
# OnlineBackup         object               0              3
# DeviceProtection     object               0              3
# TechSupport          object               0              3
# StreamingTV          object               0              3
# StreamingMovies      object               0              3
# ...

# %% [markdown]
# ## Initial Observations
#
# - Dataset contains 7,043 customer records with 21 features.
# - Target variable is `Churn`.
# - Mix of numerical and categorical features.
# - `TotalCharges` appears to have an incorrect data type.
# - Some columns have only two categories and may be label encoded.
# - The dataset is slightly imbalanced.

# %%
#print(df.dtypes)
print(df.nunique())
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
print(df['MonthlyCharges'].dtype)
# Out:
# float64

# %%
print(df['TotalCharges'].dtype)
# Out:
# object

# %%
print(df['Churn'].value_counts())
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: object

# %%
print((df['TotalCharges'] == " ").sum())
# Out:
# 11

# %% [markdown]
# This means:
# df.isnull().sum() reported 0 missing values.
# However, there are 11 blank strings (" ").
# These blank strings are hidden missing values.
#
# This is a very common real-world data quality issue.
# we will hand these values first.

# %% [markdown]
# **Professional Data Cleaning**

# %%
# step 1: Replace Blank string with NaN
df['TotalCharges'] = df['TotalCharges'].replace(" ", np.nan)

# %%
print((df['TotalCharges'] == " ").sum())
# Out:
# 0

# %%
# After replacing there is 11 null values in TotalCharges feature.
print(df["TotalCharges"].isnull().sum())
# Out:
# 11

# %%
# step 2: Convert to Numeric 
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors="coerce")
# The errors="coerce" argument converts any non-numeric values into NaN, 
# which is a professional and safe approach.

# %%
# verify data type 
print(df['TotalCharges'].dtype)
# Out:
# float64

# %%
# Chech missing values again
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# Now we remove these missing values

# %%
df.dropna()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0     7590-VHVEG  Female              0     Yes         No       1           No  No phone service             DSL             No          Yes               No          No          No              No  Month-to-month              Yes           Electronic check           29.85         29.85    No
# 1     5575-GNVDE    Male              0      No         No      34          Yes                No             DSL            Yes           No              Yes          No          No              No        One year               No               Mailed check           56.95       1889.50    No
# ...

# %%
# Again verify the dataset size
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# missing values still exist so we fill these values with
# df["TotalCharges"] = df["TotalCharges"].fillna(0)

# %%
df["TotalCharges"] = df["TotalCharges"].fillna(0)

# %%
# verify
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Again verify
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# **Step 5: Now onward we will prepare data for training**

# %%
# Remove customerID because this feature has no predictive value.
df.drop(columns='customerID', inplace=True)
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# **Separate Features and Target**

# %%
X = df.drop("Churn", axis=1)
y = df["Churn"]

# %% [markdown]
# **Identify Feature Types**

# %%
numerical_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()

categorical_features = X.select_dtypes(include=["object"]).columns.tolist()

# %%
print("Numerical Features:")
print(numerical_features)

print()

print("Categorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']
#
# Categorical Features:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
